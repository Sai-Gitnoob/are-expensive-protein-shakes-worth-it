# %%
import pandas as pd

# %%
pd.read_csv("/home/sai/College/Projects/Protein Shakes DA/Data.csv")
# Out:
#                        Product name Brand Name  Serving Size (ml)  \
# 0                Amul Protein Shake       Amul                200
# 1  Epigamia Turbo Protein Milkshake   Epigamia                250
# 2             Raw Protein Milkshake        Raw                200
# 3            Yoga Bar Protein Shake   Yoga Bar                200
# 4             Provilac High Protein   Provilac                250
# 5            Phab Protein Milkshake       Phab                200
# 6           Nuvie Protein Milkshake      Nuvie                200
#
#    Protein per Serving (g)  Price (INR)                  Protein Type  \
# 0                       20           50                  Milk Protein
# 1                       26          150                  Whey Protein
# 2                       20          140                  Whey Protein
# 3                       20          120           Whey + Milk Protein
# 4                       30          180          Whey Protein Isolate
# ...
